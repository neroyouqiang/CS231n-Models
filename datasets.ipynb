# %%
# %load_ext autoreload
# %autoreload 2

from datasets import DataCifar10, DataCocoFeat, DataImageNet, DataMNIST
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Cifar10
dataloader = DataCifar10('./datasets/cifar-10-batches-py')
dataloader.show_info()
dataloader.show_by_data(dataloader.x_train[0: 12], dataloader.y_train[0: 12], maxflen=4)
# Out:
# Training data shape:  (50000, 3, 32, 32)
# Training labels shape:  (50000,)
# Validating data shape:  (0, 3, 32, 32)
# Validating labels shape:  (0,)
# Testing data shape:  (10000, 3, 32, 32)
# Testing labels shape:  (10000,)

# %%
# VGG16-fc7 feature of COCO
dataloader = DataCocoFeat('./datasets/coco_captioning', pca_features=False)
dataloader.show_info()
# Out:
# Training data shape:  (400135, 4096)
# Training labels shape:  (400135, 17)
# Validation data shape:  (195954, 4096)
# Validation labels shape:  (195954, 17)
# Number of training images:  82783
# Number of validation images:  40504
# Number of words:  1004

# %%
# MNIST
dataloader = DataMNIST('./datasets/mnist_data/')
dataloader.show_info()
dataloader.show_by_data(dataloader.x_train[0: 12], dataloader.y_train[0: 12], maxflen=4)
# Out:
# Training data shape:  (60000, 1, 28, 28)
# Training labels shape:  (60000,)
# Validating data shape:  (0, 1, 28, 28)
# Validating labels shape:  (0,)
# Testing data shape:  (10000, 1, 28, 28)
# Testing labels shape:  (10000,)

# %%
# ImageNet(only 25 images) 
dataloader = DataImageNet('./datasets/imagenet_val_25')
dataloader.show_info()
dataloader.show_by_data(dataloader.x_train[0: 6], dataloader.y_train[0: 6], maxflen=2)
# Out:
# Training data shape:  (25, 3, 224, 224)
# Training labels shape:  (25,)
